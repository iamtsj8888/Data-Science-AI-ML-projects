# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
market_analysis_path = 'market_analysis.csv'
df = pd.read_csv(market_analysis_path, delimiter=';', decimal=',')

# %%
df.head()
# Out:
#    unified_id    month  zipcode           city  host_type  bedrooms bathrooms  \
# 0    10000347   2020-1    92315  Big Bear Lake  2-5 Units       3.0         2
# 1    10000347  2020-10    92315  Big Bear Lake  2-5 Units       3.0         2
# 2    10000347  2020-11    92315  Big Bear Lake  2-5 Units       3.0         2
# 3    10000347  2020-12    92315  Big Bear Lake  2-5 Units       3.0         2
# 4    10000347   2020-2    92315  Big Bear Lake  2-5 Units       3.0         2
#
#   guests       revenue  openness  occupancy  nightly rate  lead time  \
# 0     10    899.959992      31.0   0.064516    449.979996       52.0
# 1     10  13950.000000      31.0   1.000000    450.000000        NaN
# 2     10  13500.000000      30.0   1.000000    450.000000        NaN
# 3     10  13950.000000      31.0   1.000000    450.000000        NaN
# 4     10    450.000000      29.0   0.034483    450.000000        8.0
#
#    length stay
# 0          3.0
# 1          NaN
# 2          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34784 entries, 0 to 34783
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unified_id    34784 non-null  int64
#  1   month         34784 non-null  object
#  2   zipcode       34784 non-null  int64
#  3   city          34784 non-null  object
#  4   host_type     34784 non-null  object
#  5   bedrooms      34783 non-null  float64
#  6   bathrooms     34783 non-null  object
#  7   guests        34783 non-null  object
#  8   revenue       34779 non-null  float64
#  9   openness      34783 non-null  float64
#  10  occupancy     34783 non-null  float64
#  11  nightly rate  27706 non-null  float64
#  12  lead time     25317 non-null  float64
#  13  length stay   25317 non-null  float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 3.7+ MB

# %%
df["bedrooms"]=df["bedrooms"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34784 entries, 0 to 34783
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unified_id    34784 non-null  int64
#  1   month         34784 non-null  object
#  2   zipcode       34784 non-null  int64
#  3   city          34784 non-null  object
#  4   host_type     34784 non-null  object
#  5   bedrooms      34784 non-null  object
#  6   bathrooms     34783 non-null  object
#  7   guests        34783 non-null  object
#  8   revenue       34779 non-null  float64
#  9   openness      34783 non-null  float64
#  10  occupancy     34783 non-null  float64
#  11  nightly rate  27706 non-null  float64
#  12  lead time     25317 non-null  float64
#  13  length stay   25317 non-null  float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 3.7+ MB

# %%
df["city"].value_counts().plot(kind="bar")
plt.show()

# %%
df["month"].value_counts().plot(kind="bar")
plt.show()

# %%
df["guests"].value_counts().plot(kind="bar")
plt.show()

# %%
df["bedrooms"].value_counts().plot(kind="bar")
plt.show()

# %%
df["bathrooms"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.boxplot(df["revenue"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ea994df160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ea994df610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ea994deec0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ea994dfb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ea994dfdf0>],
#  'means': []}

# %%
df.describe().T
# Out:
#                 count          mean           std        min           25%  \
# unified_id    34784.0  2.094313e+07  6.563164e+06  119838.00  1.703086e+07
# zipcode       34784.0  9.230616e+04  2.015093e+01   92252.00  9.231400e+04
# revenue       34779.0  6.112875e+03  7.691587e+03       0.00  9.455000e+02
# openness      34783.0  2.834387e+01  6.265671e+00       1.00  3.000000e+01
# occupancy     34783.0  4.744358e-01  3.584180e-01       0.00  1.250000e-01
# nightly rate  27706.0  4.474203e+02  3.353116e+02      11.99  2.402363e+02
# lead time     25317.0  4.113127e+01  4.531975e+01       1.00  1.427273e+01
# length stay   25317.0  5.965424e+00  1.895315e+01       1.00  2.000000e+00
#
#                        50%           75%         max
# unified_id    2.114922e+07  2.632785e+07  30680441.0
# zipcode       9.231500e+04  9.231500e+04     92315.0
# revenue       4.324000e+03  8.472000e+03    151900.0
# openness      3.000000e+01  3.100000e+01        31.0
# ...

# %%
plt.hist(df["revenue"],bins=20)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34784 entries, 0 to 34783
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unified_id    34784 non-null  int64
#  1   month         34784 non-null  object
#  2   zipcode       34784 non-null  int64
#  3   city          34784 non-null  object
#  4   host_type     34784 non-null  object
#  5   bedrooms      34784 non-null  object
#  6   bathrooms     34783 non-null  object
#  7   guests        34783 non-null  object
#  8   revenue       34779 non-null  float64
#  9   openness      34783 non-null  float64
#  10  occupancy     34783 non-null  float64
#  11  nightly rate  27706 non-null  float64
#  12  lead time     25317 non-null  float64
#  13  length stay   25317 non-null  float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 3.7+ MB

# %%
plt.hist(df["nightly rate"])
plt.show()

# %%
plt.hist(df["length stay"],bins=50)
plt.show()

# %%
sns.scatterplot(x="nightly rate",y="length stay",data=df)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>

# %%
sns.scatterplot(x="nightly rate",y="length stay",hue="guests",data=df)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>

# %%
data=df[df["guests"]=="8"]
sns.scatterplot(x="nightly rate",y="length stay",hue="guests",data=data)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>

# %%
df["guests"].value_counts()
# Out:
# 8      9853
# 6      5992
# 10     5689
# 7      3020
# 12     2562
# 9      2248
# 15+    1847
# 11     1231
# 14     1054
# 5       659
# 13      503
# 4       125
# Name: guests, dtype: int64

# %%
data.head()
# Out:
#     unified_id    month  zipcode           city      host_type bedrooms  \
# 30    10052559   2020-1    92315  Big Bear Lake  Professionals      3.0
# 31    10052559  2020-10    92315  Big Bear Lake  Professionals      3.0
# 32    10052559  2020-11    92315  Big Bear Lake  Professionals      3.0
# 33    10052559  2020-12    92315  Big Bear Lake  Professionals      3.0
# 34    10052559   2020-2    92315  Big Bear Lake  Professionals      3.0
#
#    bathrooms guests  revenue  openness  occupancy  nightly rate  lead time  \
# 30       2.5      8  10055.0      31.0   0.516129    628.437500  20.714286
# 31       2.5      8  20959.0      31.0   1.000000    676.096774  18.000000
# 32       2.5      8  13622.0      30.0   0.733333    619.181818  22.600000
# 33       2.5      8  16185.0      31.0   0.612903    851.842105  12.272727
# 34       2.5      8   6000.0      29.0   0.344828    600.000000  16.666667
#
#     length stay
# 30     2.428571
# 31     9.000000
# 32     4.400000
# ...

# %%
data=df[df["guests"]=="15+"]
sns.scatterplot(x="nightly rate",y="length stay",hue="guests",data=data)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>

# %%
data=df[df["guests"]=="15+"]
sns.scatterplot(x="nightly rate",y="length stay",hue="bathrooms",data=data)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>

# %%
data=df[df["guests"]=="15+"]
sns.scatterplot(x="nightly rate",y="length stay",hue="bedrooms",data=data)
# Out:
# <Axes: xlabel='nightly rate', ylabel='length stay'>
